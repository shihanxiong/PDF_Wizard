# %%
'''
Shuffle PDF odd even pages
@author: Hanxiong Shi
'''
import os

oddPath = os.getcwd() + '\input\odd.pdf'
evenPath = os.getcwd() + '\input\even.pdf'
evenReversePath = os.getcwd() + '\input\even_reverse.pdf'
outputPath = os.getcwd() + '\output\generated.pdf'

# %%
'''
odd + even reversed page
  $pdftk A=odd.pdf B=even_reverse.pdf shuffle A Bend-1 output collated_pages.pdf

odd + even page
  $pdftk A=odd.pdf B=even.pdf shuffle A B output collated_pages.pdf
'''
# Out:
# 0
